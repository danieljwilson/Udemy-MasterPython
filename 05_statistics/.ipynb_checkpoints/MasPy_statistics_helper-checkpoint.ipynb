# %% [markdown]
# # COURSE: Master Python for scientific programming by solving projects
# ## PROJECT: Statistics
# #### TEACHER: Mike X Cohen, sincxpress.com
# ##### COURSE URL: udemy.com/course/maspy_x/?couponCode=202010

# %%
# import all necessary modules
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# # Download and inspect the data

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv"

data = pd.read_csv(url, sep=';')
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# describe the data
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# list number of unique values per column

for col in data.columns:
    u_vals = len(np.unique(data[col]))
    print(f'{col} has {u_vals} unique values')
# Out:
# fixed acidity has 96 unique values
# volatile acidity has 143 unique values
# citric acid has 80 unique values
# residual sugar has 91 unique values
# chlorides has 153 unique values
# free sulfur dioxide has 60 unique values
# total sulfur dioxide has 144 unique values
# density has 436 unique values
# pH has 89 unique values
# sulphates has 96 unique values
# alcohol has 65 unique values
# quality has 6 unique values

# %%
# plot some data
fig,ax = plt.subplots(1,figsize=(17,4))

# data.boxplot()
ax = sns.boxplot(data=data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45)

plt.show()

# %%
# remove rows with outliers
# based of being more than 3 sd from the mean
data = data[(np.abs(stats.zscore(data)) < 4).all(axis=1)]

# %%
# some exploration (scatterplot of any two columns)
sns.scatterplot(x=data['residual sugar'], y=data['alcohol'])
plt.show()

# pairwise plots (pick three columns)
sns.pairplot(data, vars=data.columns[:3],
             palette='colorblind',
             kind='reg',
             diag_kind='kde',
             hue='quality'
            )
plt.show()

# %% [markdown]
# # T-test for acidity on wine quality

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
ttest[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-0d62e2bbba40> in <module>
# ----> 1 ttest[0]
#
# NameError: name 'ttest' is not defined

# %%
# t-test of volatile acidity on quality=3 vs. 8

x = data.loc[data['quality']==3, 'volatile acidity']
y = data.loc[data['quality']==8, 'volatile acidity']
ttest = stats.ttest_ind(x,y)

# show the data in a plot
plt.plot(np.random.randn(len(x))/30, x, 'o',
         np.random.randn(len(y))/30+1, y, 'o',
        )
plt.xlim(-1, 2)
plt.xticks([0,1],labels=['Qual 3','Qual 8'])
plt.title(f't={ttest[0]:.2f}, p={ttest[1]:.5f}')
plt.ylabel('volatile acidity')
plt.show()

# %%
# show a histogram of quality scores

plt.hist(data.quality);

# %%
data['quality'].value_counts().sort_index().plot(kind='bar', rot=0);

# %%
# t-test of volatile acidity on quality=3 vs. 8

x = data.loc[(data['quality']==3) | (data['quality']==4), 'volatile acidity']
y = data.loc[(data['quality']==8) | (data['quality']==7), 'volatile acidity']
ttest = stats.ttest_ind(x,y)

# show the data in a plot
plt.plot(np.random.randn(len(x))/30, x, 'o',
         np.random.randn(len(y))/30+1, y, 'o',
         markeredgecolor = 'k'
        )
plt.xlim(-1, 2)
plt.xticks([0,1],labels=['Qual 3+4','Qual 7+8'])
plt.title(f't={ttest[0]:.2f}, p={ttest[1]:.5f}')
plt.ylabel('volatile acidity')
plt.show()

# %% [markdown]
# # Multiple regression

# %%
import statsmodels.api as sm

# %%
# predict quality from all other columns; show in a table or something

dep_var  =  data['quality'] # dependent variable
ind_vars =  data.drop(columns='quality') # independent variables
ind_vars =  sm.add_constant(ind_vars) # add an intercept term 

# setup and run the model
model = sm.OLS(dep_var, ind_vars).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                quality   R-squared:                       0.378
# Model:                            OLS   Adj. R-squared:                  0.374
# Method:                 Least Squares   F-statistic:                     84.42
# Date:                Mon, 31 May 2021   Prob (F-statistic):          7.67e-149
# Time:                        12:40:27   Log-Likelihood:                -1488.0
# No. Observations:                1537   AIC:                             3000.
# Df Residuals:                    1525   BIC:                             3064.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   19.6258     22.599      0.868      0.385     -24.703      63.954
# ...

# %%
sig_cols = list(model.pvalues[model.pvalues< .05].keys())
for col in sig_cols:
    print(col)
# Out:
# volatile acidity
# citric acid
# chlorides
# total sulfur dioxide
# pH
# sulphates
# alcohol

# %%
[print(i) for i in sig_cols];
# Out:
# volatile acidity
# citric acid
# chlorides
# total sulfur dioxide
# pH
# sulphates
# alcohol

# %%
# vertical list of all significant (p<.05) columns

sig_cols.append('quality')


# pairwise plots just for significant effects
sns.pairplot(data[sig_cols], kind='reg',
             hue='quality'
            )
plt.show()

# %%
#

# %% [markdown]
# # Logistic regression

# %%
# binarize wine quality

# binarization threshold
binthresh = 

# call the new column 'binquality'

# %%
# create a list containing columns to use in regression
# this is all the columns except for quality and binquality

Xcols = []

# %%
# setup and run the logistic regression model
model = sm.Logit
results = model.

# have a look at the results!
results.summary()

# %%
# vertical list of significant predictors from the standard (what you computed in the previous video)
# and logistic regressions

# %% [markdown]
# # Bonus: Transform to Gaussian

# %%
n = 500
